# %% [markdown]
# ## Understanding/ Exploratory Data Analysis on Breast Cancer Data

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import warnings
warnings.filterwarnings('ignore')

# local libraries
sys.path.insert(0,'../scripts/')
from data_exploration import DataInfo # import data_information script
from plots import * # visualization plots script
from prep_data import * # data preparation

# %%
# read csv data into a datframe
data = pd.read_csv('../data/data.csv')
data.head() # view data
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #### let us explore what has been stored in it. How many data points present, the column names, datatypes of each colum, descriptive statistics of variables, presence of missing values etc. All these questions needs to be answered.

# %%
explorer = DataInfo(data)

# %%
# number of data points
explorer.get_no_datapoints()
# Out:
#  There are 569 rows and 33 columns presnet in this data

# %%
# list the 33 column names
explorer.get_column_names()
# Out:
# Columns in the data are:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  'Unnamed: 32']

# %%
# get information about the data
explorer.get_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# The data contains 32 numerical datatypes and 1 categorical datatpye with a memory usage of over 146.8 KB.

# %%
# descriptive statistics of data
explorer.get_description()
# Out:
# Descriptive statistics:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# check for total number of missing values
explorer.get_total_missing_values()
# Out:
# The number of missing value(s): 569

# %%
# percentage missing
explorer.get_percentage_missing_values()
# Out:
# There are 3.03 % missing values.

# %% [markdown]
# Let us check for columns with these missing values.

# %%
# columns with missing values
explorer.get_missing_columns()
# Out:
# Columns having missing value(s): Index(['Unnamed: 32'], dtype='object')

# %%
# check for duplicate rows
explorer.get_duplicates()
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# There are no duplicate rows

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# * Count of cancer type

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
plot_count(data,'diagnosis')

# %% [markdown]
# Most breast cancer cases were diagnosed as benign

# %% [markdown]
# Number of Malign and Bening is shown above, with over 350 Bening and Malign slightly over 200  diagnosed.

# %%
plot_pie(data,'diagnosis')

# %% [markdown]
# Diagnosis Column have 2 unique values Malignant(M) and Benign(B) having count of 37.3 and 62.7 percent respectively.

# %% [markdown]
# * Heatmap

# %% [markdown]
# To find the most correlated features

# %%
plot_heat(data)

# %% [markdown]
# Scatter pots of some positively correlated features

# %%
#fig, ax = plt.subplots(2, 2, figsize=(15, 15))
plot_scatter(data, 'radius_mean', 'perimeter_mean')
plot_scatter(data, 'perimeter_mean','area_mean')
plot_scatter(data, 'radius_se','perimeter_se')
plot_scatter(data, 'radius_worst', 'area_mean')

# %% [markdown]
# Scatter plots for negatively correlated features

# %%
plot_scatter(data,'smoothness_se','area_mean')
plot_scatter(data, 'texture_se', 'compactness_worst')

# %% [markdown]
# Scatter plots of uncorrelated features i.e correlation = 0

# %%
plot_scatter(data,'radius_mean','fractal_dimension_se')
plot_scatter(data,'compactness_mean','radius_se')

# %% [markdown]
# * Distribution of attributes

# %%
#some plots for radius
plot_distribution(data,'radius_mean')
plot_distribution(data,'radius_se')
plot_distribution(data,'radius_worst')

# %%
plot_hist(data,'radius_mean','red')

# %%
plot_hist(data, 'texture_worst', 'blue')

# %%
# drop unwanted columns
data = data.drop(['id','Unnamed: 32'], axis=1)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Feature scaling

# %%
scaled_features = feature_scaling(data,'diagnosis')
scaled_features.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0     1.097064     -2.073335        1.269934   0.984375
# 1          0     1.829821     -0.353632        1.685955   1.908708
# 2          0     1.579888      0.456187        1.566503   1.558884
# 3          0    -0.768909      0.253732       -0.592687  -0.764464
# 4          0     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
to_csv(data)
# Out:
# Data saved successfully...
